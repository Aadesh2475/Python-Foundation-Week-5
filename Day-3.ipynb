# %%
# !pip install seaborn matplotlib pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: matplotlib in c:\users\jaddu\appdata\roaming\python\python313\site-packages (3.10.8)
# Requirement already satisfied: pandas in c:\users\jaddu\appdata\roaming\python\python313\site-packages (3.0.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\jaddu\appdata\roaming\python\python313\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jaddu\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jaddu\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jaddu\appdata\roaming\python\python313\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jaddu\appdata\roaming\python\python313\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jaddu\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\jaddu\appdata\roaming\python\python313\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\jaddu\appdata\roaming\python\python313\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jaddu\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\jaddu\appdata\roaming\python\python313\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\jaddu\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = sns.load_dataset("tips")

# 1. Histplot
sns.histplot(df['total_bill'])
plt.show()

# 2. KDE plot
sns.kdeplot(df['total_bill'])
plt.show()

# 3. Combined
sns.histplot(df['total_bill'], kde=True)
plt.show()

# 4. Compare distributions
sns.histplot(data=df, x="total_bill", hue="sex", kde=True)
plt.show()

# 5. Styling
sns.set_style("darkgrid")
sns.histplot(df['total_bill'], kde=True, color="purple")
plt.show()
